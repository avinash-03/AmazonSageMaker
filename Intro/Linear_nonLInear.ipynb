# %% [markdown]
# # Linear, Non-Linear Examples
#
# Objective: visualize linear,quadratic, cubic,exponential,log,sine
#     functions on plot

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns
# %matplotlib inline

# %%
def log_func(x):
    if x>0 :
        return math.log(x,10)
    else:
        return np.nan

# %%
df = pd.DataFrame(index=range(-200,200))
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [-200, -199, -198, -197, -196, -195, -194, -193, -192, -191, -190, -189, -188, -187, -186, -185, -184, -183, -182, -181, -180, -179, -178, -177, -176, -175, -174, -173, -172, -171, -170, -169, -168, -167, -166, -165, -164, -163, -162, -161, -160, -159, -158, -157, -156, -155, -154, -153, -152, -151, -150, -149, -148, -147, -146, -145, -144, -143, -142, -141, -140, -139, -138, -137, -136, -135, -134, -133, -132, -131, -130, -129, -128, -127, -126, -125, -124, -123, -122, -121, -120, -119, -118, -117, -116, -115, -114, -113, -112, -111, -110, -109, -108, -107, -106, -105, -104, -103, -102, -101, ...]
#
# [400 rows x 0 columns]

# %%
title = ["Linear 3*X","Quadratic X^2","Cubic X^3",
        "Absolute abs(X)","Sine(X)","log(x)","Exponential 2^X"]

df['linear']=df.index.map(lambda x: 3*x)

df['quadratic']=df.index.map(lambda x: x**2)

df['cubic']=df.index.map(lambda x:x^3)

df['abs']= df.index.map(lambda x:abs(x))

df['sine']= np.sin(np.arange(-20,20,.1))

df['log']=df.index.map(log_func)

df['exponential'] = df.index.map(lambda x:2.0**x)

# %%
df.head()
# Out:
#       linear  quadratic  cubic  abs      sine  log   exponential
# -200    -600      40000   -197  200 -0.912945  NaN  6.223015e-61
# -199    -597      39601   -198  199 -0.867644  NaN  1.244603e-60
# -198    -594      39204   -199  198 -0.813674  NaN  2.489206e-60
# -197    -591      38809   -200  197 -0.751573  NaN  4.978412e-60
# -196    -588      38416   -193  196 -0.681964  NaN  9.956824e-60

# %%
df.tail()
# Out:
#      linear  quadratic  cubic  abs      sine       log   exponential
# 195     585      38025    192  195  0.605540  2.290035  5.021681e+58
# 196     588      38416    199  196  0.681964  2.292256  1.004336e+59
# 197     591      38809    198  197  0.751573  2.294466  2.008673e+59
# 198     594      39204    197  198  0.813674  2.296665  4.017345e+59
# 199     597      39601    196  199  0.867644  2.298853  8.034690e+59

# %%
fig,axs = plt.subplots(2,2,figsize=(10,10),sharex=False)

axx=axs.ravel()

for i in range(df.shape[1]-3):
    axx[i].set_title(title[i])
    df[df.columns[i]].plot(ax=axx[i])
    axx[i].set_xlabel('x')
    if i%2==1:
        axx[i].yaxis.tick_right()
    axx[i].grid()

# %%
# Exponential 

plt.figure(figsize=(10,3))
plt.plot(df['exponential'])
plt.title("Exponential 2^X")
plt.xlim(-10,20)
plt.ylim(0,100000)
plt.xlabel("x")
plt.grid()

# %%
# Log
plt.figure(figsize=(10,3))
plt.plot(df['log'])
plt.title("Log(X)")
plt.xlim(-10,200)
plt.xlabel("X")
plt.grid()

# %%
# sine
plt.figure(figsize=(10,3))
plt.plot(df['sine'])

plt.title("Sine(X)")
plt.xlabel("x")
plt.grid()
